# %% [markdown]
# <a href="https://colab.research.google.com/github/yashu0107/python-record/blob/main/exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Aim="1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark"
print(Aim)

m1 = int(input("Enter marks for Test 1: "))
m2 = int(input("Enter marks for Test 2: "))
m3 = int(input("Enter marks for Test 3: "))

minimum = min(m1, m2, m3)

sum_best_two = m1 + m2 + m3 - minimum

average_best_two = sum_best_two / 2

print("Average of best two test marks is:", average_best_two)
# Out:
# 1.Calculation of Test Average: Write a python program to find the best of two test average marks out of three test’s mark
# Enter marks for Test 1: 23
# Enter marks for Test 2: 58
# Enter marks for Test 3: 69
# Average of best two test marks is: 63.5
