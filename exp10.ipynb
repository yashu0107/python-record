# %% [markdown]
# <a href="https://colab.research.google.com/github/yashu0107/python-record/blob/main/exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aim="Inheritance: By using the concept of inheritance write a python program to find the areaof triangle, circle and rectangle."
import math
def area_of_triangle(base, height):
    return 0.5 * base * height
def area_of_circle(radius):
    return math.pi * radius ** 2
def area_of_rectangle(length, width):
    return length * width
# Example usage:
print("Area of triangle:", area_of_triangle(5, 10)) # base=5, height=10
print("Area of circle:", area_of_circle(7)) # radius=7
print("Area of rectangle:", area_of_rectangle(4, 8)) # length=4, width=8
# Out:
# Area of triangle: 25.0
# Area of circle: 153.93804002589985
# Area of rectangle: 32
