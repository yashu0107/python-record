# %% [markdown]
# <a href="https://colab.research.google.com/github/yashu0107/python-record/blob/main/exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aim="Find Palindrome and Character Frequency"
print(aim)

input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
 print("Palindrome")
else:
 print("Not Palindrome")
for ch in set(input_str):
  count = input_str.count(ch)
print(f"'{ch}' appears {count} times")
# Out:
# Find Palindrome and Character Frequency
# Enter a string: yasaswi
# Not Palindrome
# 's' appears 2 times
